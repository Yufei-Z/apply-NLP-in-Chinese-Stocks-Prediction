# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
import re
import os
import time
os.chdir('D:/股吧评论')

id = '000002'
#请求头
head ={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
'Accept-Encoding':'gzip,deflate',
'Accept-Language':'zh-CN,zh;q=0.9',
'Cache-Control':'max-age=0',
'Connection':'keep-alive',
'Cookie':'st_pvi=87732908203428;st_si=12536249509085;qgqp_b_id=9777e9c5e51986508024bda7f12e6544;_adsame_fullscreen_16884=1',
'Host':'guba.eastmoney.com',
'Referer':'http://guba.eastmoney.com/list,600596,f_1.html',
'Upgrade-Insecure-Requests':'1',
'User-Agent':'Mozilla/5.0(WindowsNT6.1;Win64;x64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/65.0.3325.181Safari/537.36'}
 
#设置数据存储方式，csv表格写入
f = open('title'+id+'.csv','a',newline='')
w = csv.writer(f)
 
#获取帖子详细时间，列表也没有年份，可以作为获取帖子其他详细内容的通用方法
def get_time(url):
    try:
        q = requests.get(url,headers=head)
        soup = BeautifulSoup(q.text,'html.parser')
        ptime = soup.find('div',{'class':'zwfbtime'}).get_text()
        ptime = re.findall(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}',ptime)[0]
        #print(ptime)
        return ptime
    except:
        return ''

#获取列表页第n页的具体目标信息，由BeautifulSoup解析完成
def get_urls(url):
    baseurl = 'http://guba.eastmoney.com/'
    q = requests.get(url,headers=head,verify=False)
    soup = BeautifulSoup(q.text,'html.parser')
    urllist = soup.findAll('div',{'class':'articleh normal_post'})
    print(len(urllist))
    for i in urllist:
        if i.find('a') != None:
            try:
                detailurl = i.find('a').attrs['href'].replace('/','')
               # print(detailurl)
                title = i.find('a').get_text()
                read = i.find('span',{'class':'l1'}).get_text()
                comment = i.find('span', {'class': 'l2'}).get_text()
                time = get_time(baseurl+detailurl)
                w.writerow([detailurl,title,read,comment,time])
               # print(baseurl + detailurl)
            except:
                pass
#循环所有页数

url = 'http://guba.eastmoney.com/list,'+id+',f_'
for i in range(1,50):
    print(i)
    if i% 25 ==0:
        
        print('-----------sleep----------')
        time.sleep(60)
    get_urls(url+str(i)+'.html')
# Out:
# 1
# 81

# %%
import urllib.request
import requests
headers ={
'Accept':'*/*',
#'Cache-Control':' private, no-store, no-cache, must-revalidate, max-age=0',
'Connection':'keep-alive',
'Host': 'xueqiu.com',
'Cookie':'xq_a_token.sig=TIigUHtW6VQxXvSEOwIOURxn6V0; xq_r_token.sig=bS2mSsfHTJcugqefE9LcNGpCqZ8; xqat.sig=mPd6Qjk06dbsOgDQMdBGs5bcwwc; device_id=078fc8a1158fb5f5fb3d6e42c8bc1c24; cookiesu=921582127825041; Hm_lvt_1db88642e346389874251b5a1eded6e3=1581613576; s=c11364qr9j; xq_a_token=593f24f8c5a0eb6b074dcd536166c24aa3764fcd; xqat=593f24f8c5a0eb6b074dcd536166c24aa3764fcd; xq_r_token=b7cad1cf27d7db41e2a1bb1143499dff3da75c58; xq_id_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJ1aWQiOjI5NjY5NTU5MjEsImlzcyI6InVjIiwiZXhwIjoxNTg0NzE5OTI0LCJjdG0iOjE1ODIxMjc5MjQyMTYsImNpZCI6ImQ5ZDBuNEFadXAifQ.YDL8DnoYptHukaPztHD_TKhXzDLWfTaZLyhM5oIZmjJf_vD_IwpwupVPLA6Hsl1laRgC9IuN4_ugTzXStTPUGcoVP4oSbIA7ArBfJXH2CjhwRMLd0SHYg2c7ZnAYJnfRk6sbHt15AhtPOz4iXHMYFkyfLTjJD8FSJLJyRMa0nYdnCCOZkaKoE8iPI8SIapXblLyJ6tm75jZq6GLpjZF-ZL2zTkjRBapHTFTulal4s1iFHFSpfKKkdBxxCcUHXOE-WqrhSr0HvQ45IQEvYeejOo5eq6-A4gA8qQNmXqMALpFs-iee8DlENicHQ3iUBviV4L_v8udg5YJ5f6mIkEzEWw; xq_token_expire=Sun%20Mar%2015%202020%2023%3A58%3A44%20GMT%2B0800%20(China%20Standard%20Time); xq_is_login=1; u=2966955921; snbim_minify=true; bid=1fca7fb44a8ea5bd83444f5a11d415c2_k6uynszx; __utma=1.1287029275.1582216178.1582216178.1582216178.1; __utmc=1; __utmz=1.1582216178.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); Hm_lpvt_1db88642e346389874251b5a1eded6e3=1582814743',



'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
 
urls='https://xueqiu.com/query/v1/symbol/search/status?u=2966955921&uuid=1233040698702458880&count=10&comment=0&symbol=SH601939&hl=0&source=all&sort=&page=4&q=&session_token=null&access_token=593f24f8c5a0eb6b074dcd536166c24aa3764fcd'
#req = urllib.request.Request(url,headers=headers)
#html = urllib.request.urlopen(req).read().decode('utf-8')
q = requests.get(urls,headers=headers)
soup = BeautifulSoup(q.text,'html.parser')

# %%
get_urls('http://guba.eastmoney.com/list,601398,f_32.html')

# %%
#著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。

import urllib.request
headers = {'X-Requested-With': 'XMLHttpRequest',
           'Referer': 'http://xueqiu.com/p/ZH010389',
           'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64; rv:38.0) Gecko/20100101 Firefox/38.0',
           'Host': 'xueqiu.com',
           #'Connection':'keep-alive',
           #'Accept':'*/*',
           'cookie':'s=iabht2os.1dgjn9z; xq_a_token=02a16c8dd2d87980d1b3ddced673bd6a74288bde; xq_r_token=024b1e233fea42dd2e0a74832bde2c914ed30e79; __utma=1.2130135756.1433017807.1433017807.1433017807.1;'
           '__utmc=1; __utmz=1.1433017807.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); Hm_lvt_1db88642e346389874251b5a1eded6e3=1433017809; Hm_lpvt_1db88642e346389874251b5a1eded6e3=1433017809'}

url = 'http://xueqiu.com/cubes/rebalancing/history.json?cube_symbol=ZH010389&count=20&page=1'
req = urllib.request.Request(url,headers=headers)
html = urllib.request.urlopen(req).read().decode('utf-8')
print(html)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-25e7e31b196a> in <module>
#      13 url = 'http://xueqiu.com/cubes/rebalancing/history.json?cube_symbol=ZH010389&count=20&page=1'
#      14 req = urllib.request.Request(url,headers=headers)
# ---> 15 html = urllib.request.urlopen(req).read().decode('utf-8')
#      16 print(html)
#
# D:\anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# D:\anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
# ...

# %%
#!pip install socket
import socket
socket.getaddrinfo('127.0.0.1' , 8080)
# Out:
# [(<AddressFamily.AF_INET: 2>, 0, 0, '', ('127.0.0.1', 8080))]

# %%
url=url+str(1)+'.html'

# %%
baseurl = 'http://guba.eastmoney.com/'
q = requests.get(url,headers=head)
soup = BeautifulSoup(q.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta charset="utf-8"/>
# <title></title>
# <meta name="keywords"/>
# <meta name="description"/>
# <link href="//gbfek.dfcfw.com/project/guba/release/error404.css?r=106" rel="stylesheet"/>
# <base target="_blank"/>
# </head>
# <body class="hlbody">
# <style>
#     #topnav .guba_topic {
#         height: 38px;
#     }
#
#     #topnav .gubatopic {
#         top: 35px;
#         left: -20px;
#     }
#
#         #topnav .gubatopic li {
#             background: #fff !important;
#             float: left;
#             line-height: 30px;
#         }
# </style>
# <div id="header">
# <!-- 微信分享img -->
# <img id="weixin-share" src="http://cmsjs.eastmoney.com/common/weixin-share.png" style="position: absolute; width: 0; height: 0; left: -1000px;z-index: -1;"/>
# <div class="gbbody" id="headergbbody">
# <ul id="topnav">
# ...

# %%
soup.findAll('div',{'class':'articleh'})
# Out:
# []

# %%
url
# Out:
# 'http://guba.eastmoney.com/list,601939.html,f_1.html'
